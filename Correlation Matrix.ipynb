# %% [markdown]
# # Imports

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Ticker List, Scrape Data from Yahoo Finance

# %%
# ticker list and create dataframe for 1yr performance of stock data


tickers = ['XTN','VOE','GOOG','CCL','DAC','IPI'] #ticker list

df = yf.download(tickers, period="5y", interval= '1d', ignore_tz=True) # yahoo finance
# Out:
# [*********************100%***********************]  6 of 6 completed

# %% [markdown]
# # Index by Closing Price, Calculate Daily Percent Change

# %%
adj_close = df['Adj Close'] #index by adjusted close
returns = adj_close.pct_change() #daily change in price

# %% [markdown]
# # Stock Charts

# %%
# charting
adj_close.plot(figsize=(10,20), subplots=True) 
plt.show()

# %% [markdown]
#  # Correlation Matrix

# %%
correlation_matrix = returns.corr()

plt.figure(figsize = (16, 6))
sns.heatmap(correlation_matrix, annot=True)
plt.title("Heidtke Fund Correlation Matrix", fontsize=24)
plt.show()

# %% [markdown]
# # Minimum, Maximum Correlation & Std Dev Values

# %%
#miximum correlation
print(f"Maximum correlation: {correlation_matrix.min().max()}")
np.fill_diagonal(correlation_matrix.values, 0)

#maximum correlation
print(f"Maximum correlation: {correlation_matrix.max().max()}")
np.fill_diagonal(correlation_matrix.values, 1)

#standard deviation
print('\n standard deviation\n', adj_close.std())
# Out:
# Maximum correlation: 0.3952678921815195
# Maximum correlation: 0.8765083997239518
#
#  standard deviation
#  CCL     17.950042
# DAC     28.893203
# GOOG    30.970587
# IPI     15.918023
# VOE     19.958420
# XTN     12.901009
# dtype: float64
